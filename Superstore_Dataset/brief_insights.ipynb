# %% [markdown]
# # Brief Business Insights
# ## CEI SQL Task 2 - Week 2 | Superstore Dataset Analysis
#
# ---
#
# ## 1. Dataset Overview
# - **Total Records:** 9,994 order items
# - **Total Unique Orders:** 5,009
# - **Total Unique Customers:** 793
# - **Total Unique Products:** 1,862
# - **Date Range:** 2014 to 2018
# - **Total Revenue:** $1,099,862.07
#
# ---
#
# ## 2. Category Performance
# | Category | Avg Price | Max Price | Min Price |
# |----------|-----------|-----------|-----------|
# | Technology | $589.52 | $22,638 | $0.99 |
# | Furniture | $315.01 | $3,083 | $2.03 |
# | Office Supplies | $116.35 | $9,449 | $1.08 |
#
# **Insight:** Technology dominates in price range but Office Supplies likely has highest volume.
#
# ---
#
# ## 3. Top 10 Customers by Revenue
# | Rank | Customer | Total Spent |
# |------|----------|-------------|
# | 1 | Adrian Barton | $12,120.60 |
# | 2 | Hunter Lopez | $11,713.83 |
# | 3 | Tom Ashbrook | $11,649.21 |
# | 4 | Sanjit Engle | $10,639.66 |
# | 5 | Bill Shonely | $10,351.02 |
# | 6 | Christopher Conant | $8,953.38 |
# | 7 | Grant Thornton | $8,174.86 |
# | 8 | Tom Boeckenhauer | $7,291.96 |
# | 9 | Joseph Holt | $6,695.55 |
# | 10 | Alex Avila | $6,606.48 |
#
# **Insight:** Top 10 customers contribute significantly — focus retention efforts here.
#
# ---
#
# ## 4. Customer Segments
# - **Consumer:** 52% of customers
# - **Corporate:** 30% of customers
# - **Home Office:** 18% of customers
#
# **Insight:** Consumer segment is the largest — marketing should prioritize this segment.
#
# ---
#
# ## 5. Regional Coverage
# - **4 Regions:** South, West, East, Central
# - **United States only** — no international orders
#
# ---
#
# ## 6. Monthly Trends
# - **49 months** of sales data (2014–2018)
# - Sales data shows consistent ordering across all months
#
# ---
#
# ## 7. Data Quality
# | Check | Result |
# |-------|--------|
# | Null customer_id | 0 |
# | Null order_date | 0 |
# | Null total_amount | 0 |
# | Null status | 0 |
# | Duplicate orders | 0 |
#
# **Insight:** Dataset is clean with zero null values and no duplicate orders.
#
# ---
#
# ## 8. Key Business Recommendations
# 1. **Retain top customers** — Adrian Barton and Hunter Lopez are high-value customers
# 2. **Focus on Technology** — highest average price means higher revenue per sale
# 3. **Target Consumer segment** — largest customer base with growth potential
# 4. **Expand regionally** — analyze which region has lowest sales for growth opportunity
